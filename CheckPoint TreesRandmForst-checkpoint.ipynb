# %%
#Importing our dataset from csv file
import pandas as pd 
dataset=pd.read_csv("D:\StockageDrive\CV\GoMyCode Cours IA1/titanic-passengers.csv", sep=";")

#Preprocessing our data
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(dataset)

# %%
#importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
#features extraction
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
arbre = tree.DecisionTreeClassifier()  
arbre.fit(x_train, y_train)   #fitting our model
y_pred=arbre.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
x
# Out:
#      PassengerId  Pclass  Sex        Age  SibSp  Parch     Fare
# 0            343       2    1  28.000000      0      0  13.0000
# 1             76       3    1  25.000000      0      0   7.6500
# 2            641       3    1  20.000000      0      0   7.8542
# 3            568       3    0  29.000000      0      4  21.0750
# 4            672       1    1  31.000000      1      0  52.0000
# ..           ...     ...  ...        ...    ...    ...      ...
# 886           10       2    0  14.000000      1      0  30.0708
# 887           61       3    1  22.000000      0      0   7.2292
# 888          535       3    0  30.000000      0      0   8.6625
# 889          102       3    1  29.699118      0      0   7.8958
# 890          428       2    0  19.000000      0      0  26.0000
#
# [891 rows x 7 columns]

# %%
import graphviz
d=tree.export_graphviz(arbre)
graph=graphviz.Source(d)
graph.render('tree')
graph

# %%
#L'arbre est profond et contient beaucoup de branches rendant la lecture manuelle difficile et compliquant sa lecture

# %%
#applying tree algorithm
arbre = DecisionTreeClassifier(max_depth=3,min_samples_leaf = 5)  
arbre.fit(x_train, y_train)   #fitting our model
y_pred=arbre.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8100558659217877

# %%
#On a une meilleure précision par rapport au premier arbre
d=tree.export_graphviz(arbre)
graph=graphviz.Source(d)
graph.render('tree')
graph

# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier #Importing Random Forest Classifier
from sklearn import metrics  # Importing metrics to test accuracy

x_trainForest, x_testForest, y_trainForest, y_testForest= train_test_split(x, y, test_size=0.2) #splitting data with test size of 30%

# %%
clf=RandomForestClassifier(n_estimators=10)  #Creating a random forest
clf.fit(x_trainForest, y_trainForest)  #Training our model
y_predForest=clf.predict(x_testForest)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_testForest, y_predForest))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8212290502793296

# %%
clf=RandomForestClassifier(n_estimators=5)  #Creating a random forest
clf.fit(x_trainForest, y_trainForest)  #Training our model
y_predForest5=clf.predict(x_testForest)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_testForest, y_predForest5))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.7932960893854749

# %%
clf=RandomForestClassifier(n_estimators=15)  #Creating a random forest
clf.fit(x_trainForest, y_trainForest)  #Training our model
y_predForest15=clf.predict(x_testForest)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_testForest, y_predForest15))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8603351955307262

# %%
clf=RandomForestClassifier(n_estimators=25)  #Creating a random forest
clf.fit(x_trainForest, y_trainForest)  #Training our model
y_predForest25=clf.predict(x_testForest)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_testForest, y_predForest25))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8435754189944135

# %%
clf=RandomForestClassifier(n_estimators=20)  #Creating a random forest
clf.fit(x_trainForest, y_trainForest)  #Training our model
y_predForest20=clf.predict(x_testForest)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_testForest, y_predForest20))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8379888268156425

# %%
#The best obtained accuracy is 0.86 obtained for 15 estimators
#The obtained accuracies for random forest are better than those ob
